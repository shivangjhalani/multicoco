# %%
# !git config --global user.email "shivang2004jhalani@gmail.com"
# !git config --global user.name "shivangjhalani"
# !gh auth login --hostname github.com --with-token <>

# %%
# %cd /workspace/
# !git clone https://github.com/shivangjhalani/multicoco.git
# %cd multicoco
# !git pull

# %%
# !pip install wandb datasets pillow einops timm

# %%
# !pip install "transformers[torch]"

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# %%
# !wandb login f52d8e8c2c53cf9f55b59cfb98ad26ef47efead9

# %%
# !python preprocessing/aokvqa.py
# Out:
# Processing train: 100%|██████████████████| 17056/17056 [00:25<00:00, 662.96it/s]
# Processing validation: 100%|███████████████| 1145/1145 [00:01<00:00, 667.77it/s]
# Processing test: 100%|█████████████████████| 6702/6702 [00:15<00:00, 445.96it/s]

# %%
# !find . -name '__pycache__' -exec rm -rf {} + && find . -name '*.pyc' -delete

# %%
# !python -c "import transformers; print(transformers.__file__)"

# %%
# !torchrun --nnodes 1 --nproc_per_node 1 run.py args/aokvqa_vanilla_eval.yaml
# Out:
# FlashAttention2 is not installed.
# Evaluation: 100%|█████████████████████████████| 144/144 [01:33<00:00,  1.54it/s]
# /opt/jupyter_venv/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# [rank0]:[W708 17:19:38.235233260 ProcessGroupNCCL.cpp:4718] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 as device used by this process is currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. You can pecify device_id in init_process_group() to force use of a particular device.
#
# ==================================================
# FINAL RESULTS
# ==================================================
# eval_accuracy: 0.6427947598253275
# eval_loss: -1.0
# eval_runtime: 93.8645
# eval_samples_per_second: 12.198
# eval_steps_per_second: 1.534
# ==================================================
# [rank0]:[W708 17:19:39.893785590 ProcessGroupNCCL.cpp:1479] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())

# %%
# !torchrun --nnodes 1 --nproc_per_node 1 run.py args/aokvqa_cot.yaml
# Out:
# 2025-07-08 17:19:47,124 - __main__ - INFO - MultiCoCoRunner initialized for training
# 2025-07-08 17:19:47,124 - __main__ - INFO - Initializing MultiCoCo pipeline...
# 2025-07-08 17:19:47,691 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_select_layer: -1
# 2025-07-08 17:19:47,692 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - ps_version: v2
# 2025-07-08 17:19:47,692 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - min_dynamic_patch: 1
# 2025-07-08 17:19:47,692 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - max_dynamic_patch: 12
# 2025-07-08 17:19:47,692 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_config is None. Initializing the InternVisionConfig with default values.
# 2025-07-08 17:19:47,692 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - llm_config is None. Initializing the LlamaConfig config with default values (`LlamaConfig`).
# 2025-07-08 17:19:47,693 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_select_layer: -1
# 2025-07-08 17:19:47,693 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - ps_version: v1
# 2025-07-08 17:19:47,693 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - min_dynamic_patch: 1
# 2025-07-08 17:19:47,693 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - max_dynamic_patch: 6
# FlashAttention2 is not installed.
# 2025-07-08 17:19:48,953 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.modeling_internvl_chat - INFO - num_image_token: 256
# 2025-07-08 17:19:48,954 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.modeling_internvl_chat - INFO - ps_version: v2
# 2025-07-08 17:19:50,272 - multicoco.model - INFO - MultiCoCo model initialized with 938193024 parameters
# 2025-07-08 17:19:50,272 - __main__ - INFO - Model 'OpenGVLab/InternVL3-1B-Pretrained' initialized successfully
# 2025-07-08 17:19:50,461 - multicoco.data - INFO - Loaded 17056 samples from /workspace/multicoco/data/aokvqa_train.json
# 2025-07-08 17:19:50,462 - __main__ - INFO - Training dataset loaded with 17056 samples
# 2025-07-08 17:19:50,464 - multicoco.data - INFO - Loaded 1145 samples from /workspace/multicoco/data/aokvqa_validation.json
# 2025-07-08 17:19:50,464 - __main__ - INFO - Evaluation dataset loaded with 1145 samples
# 2025-07-08 17:19:50,844 - multicoco.trainer - INFO - CoCoTrainer initialized with CoCoNut=disabled
# 2025-07-08 17:19:50,844 - __main__ - INFO - Trainer created successfully
# 2025-07-08 17:19:50,844 - __main__ - INFO - Starting training...
# /opt/jupyter_venv/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# [rank0]:[W708 17:19:50.365101918 ProcessGroupNCCL.cpp:4718] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 as device used by this process is currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. You can pecify device_id in init_process_group() to force use of a particular device.
# wandb: Currently logged in as: gunadeep2005 (gunadeep2005-pes-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /workspace/multicoco/wandb/run-20250708_171951-z837bwuw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train_cot
# wandb: ⭐️ View project at https://wandb.ai/gunadeep2005-pes-university/multicoco
# wandb: 🚀 View run at https://wandb.ai/gunadeep2005-pes-university/multicoco/runs/z837bwuw
# 2025-07-08 17:19:52,414 - multicoco.trainer - INFO - Starting epoch-based training:
# 2025-07-08 17:19:52,414 - multicoco.trainer - INFO -   Steps per epoch: 2132
# 2025-07-08 17:19:52,414 - multicoco.trainer - INFO -   Total epochs: 5
# 2025-07-08 17:19:52,414 - multicoco.trainer - INFO -   Total steps: 10660
# 2025-07-08 17:19:52,429 - multicoco.trainer - INFO -
# Starting Epoch 1/5
# Training Epoch 1:   0%|                                | 0/2132 [00:00<?, ?it/s]/opt/jupyter_venv/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:838: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Training Epoch 1/5, Step 2132/2132 (loss: 1.2109): 100%|█| 2132/2132 [06:52<00:0
# 2025-07-08 17:26:44,613 - multicoco.trainer - INFO -   Training completed - Average loss: 1.5426
# 2025-07-08 17:26:46,751 - multicoco.trainer - INFO -   Checkpoint saved: output/aokvqa_cot/checkpoint-epoch-1
# 2025-07-08 17:26:46,752 - multicoco.trainer - INFO -   Running evaluation after epoch 1...
# Evaluation:   6%|█▊                           | 72/1145 [01:17<16:36,  1.08it/s]2025-07-08 17:28:11,351 - multicoco.trainer - WARNING - Could not extract valid choice from:
# Evaluation:   7%|██▏                          | 85/1145 [01:36<20:12,  1.14s/it]2025-07-08 17:28:29,552 - multicoco.trainer - WARNING - Could not extract valid choice from:
# Evaluation:  41%|███████████▌                | 474/1145 [08:53<12:58,  1.16s/it]2025-07-08 17:35:41,418 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# Evaluation:  54%|███████████████             | 616/1145 [11:16<20:10,  2.29s/it]2025-07-08 17:38:09,637 - multicoco.trainer - WARNING - Could not extract valid choice from:
# Evaluation:  61%|█████████████████           | 699/1145 [12:51<11:22,  1.53s/it]2025-07-08 17:39:45,567 - multicoco.trainer - WARNING - Could not extract valid choice from:
# Evaluation:  66%|██████████████████▌         | 758/1145 [14:11<05:45,  1.12it/s]2025-07-08 17:40:59,461 - multicoco.trainer - WARNING - Could not extract valid choice from: 30.
# Evaluation:  67%|██████████████████▋         | 765/1145 [14:16<03:43,  1.70it/s]2025-07-08 17:41:10,339 - multicoco.trainer - WARNING - Could not extract valid choice from:
# Evaluation: 100%|███████████████████████████| 1145/1145 [20:31<00:00,  1.08s/it]
# /opt/jupyter_venv/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# 2025-07-08 17:47:18,531 - multicoco.trainer - WARNING - Could not extract valid choice from:
# 2025-07-08 17:47:18,531 - multicoco.trainer - WARNING - Could not extract valid choice from:
# 2025-07-08 17:47:18,533 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-08 17:47:18,534 - multicoco.trainer - WARNING - Could not extract valid choice from:
# 2025-07-08 17:47:18,534 - multicoco.trainer - WARNING - Could not extract valid choice from:
# 2025-07-08 17:47:18,534 - multicoco.trainer - WARNING - Could not extract valid choice from: 30.
# 2025-07-08 17:47:18,535 - multicoco.trainer - WARNING - Could not extract valid choice from:
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   New best accuracy: 0.7083
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -
# Epoch 1 Summary:
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   Training time: 1646.11s
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   Evaluation accuracy: 0.7083
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   Best accuracy so far: 0.7083
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO -   Checkpoint saved to: output/aokvqa_cot/checkpoint-epoch-1
# 2025-07-08 17:47:18,543 - multicoco.trainer - INFO - ================================================================================
# 2025-07-08 17:47:18,749 - multicoco.trainer - INFO -
# Starting Epoch 2/5
# Training Epoch 2:   0%|                                | 0/2132 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Training Epoch 2/5, Step 2132/2132 (loss: 1.2188): 100%|█| 2132/2132 [06:47<00:0
# 2025-07-08 17:54:05,961 - multicoco.trainer - INFO -   Training completed - Average loss: 1.1590
# 2025-07-08 17:54:08,168 - multicoco.trainer - INFO -   Checkpoint saved: output/aokvqa_cot/checkpoint-epoch-2
# 2025-07-08 17:54:08,168 - multicoco.trainer - INFO -   Running evaluation after epoch 2...
# Evaluation:   0%|                                      | 0/1145 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluation:  41%|███████████▌                | 473/1145 [01:11<00:48, 13.81it/s]2025-07-08 17:55:20,270 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# Evaluation:  45%|████████████▌               | 513/1145 [01:18<01:24,  7.46it/s]2025-07-08 17:55:26,484 - multicoco.trainer - WARNING - Could not extract valid choice from: 36
# Evaluation:  66%|██████████████████▌         | 758/1145 [01:56<00:53,  7.21it/s]2025-07-08 17:56:05,206 - multicoco.trainer - WARNING - Could not extract valid choice from: 30
# Evaluation:  81%|██████████████████████▌     | 922/1145 [02:12<00:16, 13.25it/s]2025-07-08 17:56:20,595 - multicoco.trainer - WARNING - Could not extract valid choice from: 22
# Evaluation: 100%|███████████████████████████| 1145/1145 [02:34<00:00,  7.40it/s]
# 2025-07-08 17:56:42,992 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-08 17:56:42,992 - multicoco.trainer - WARNING - Could not extract valid choice from: 36
# 2025-07-08 17:56:42,993 - multicoco.trainer - WARNING - Could not extract valid choice from: 30
# 2025-07-08 17:56:42,993 - multicoco.trainer - WARNING - Could not extract valid choice from: 22
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   New best accuracy: 0.7092
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -
# Epoch 2 Summary:
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   Training time: 564.25s
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   Evaluation accuracy: 0.7092
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   Best accuracy so far: 0.7092
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO -   Checkpoint saved to: output/aokvqa_cot/checkpoint-epoch-2
# 2025-07-08 17:56:42,996 - multicoco.trainer - INFO - ================================================================================
# 2025-07-08 17:56:43,926 - multicoco.trainer - INFO -
# Starting Epoch 3/5
# Training Epoch 3:   0%|                                | 0/2132 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Training Epoch 3/5, Step 1299/2132 (loss: 1.0703):  61%|▌| 1299/2132 [04:08<02:3
