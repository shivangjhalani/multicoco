# %%
# !git config --global user.email "shivang2004jhalani@gmail.com"
# !git config --global user.name "shivangjhalani"
# !gh auth login --hostname github.com --with-token <>

# %%
# %cd /workspace/
# !git clone https://github.com/shivangjhalani/multicoco.git
# %cd multicoco
# !git pull
# Out:
# /workspace
# fatal: destination path 'multicoco' already exists and is not an empty directory.
# /workspace/multicoco
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 738 bytes | 369.00 KiB/s, done.
# From https://github.com/shivangjhalani/multicoco
#    47bd62d..6a9a2cd  main       -> origin/main
# Updating 47bd62d..6a9a2cd
# Fast-forward
#  multicoco/trainer.py | 33 ++++++++++++++++++++-------------
#  1 file changed, 20 insertions(+), 13 deletions(-)

# %%
# !pip install wandb datasets pillow einops timm

# %%
# !pip install "transformers[torch]"

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126

# %%
# !wandb login f52d8e8c2c53cf9f55b59cfb98ad26ef47efead9

# %%
# !python preprocessing/aokvqa.py
# Out:
# Processing train: 100%|██████████████████| 17056/17056 [00:44<00:00, 385.30it/s]
# Processing validation: 100%|███████████████| 1145/1145 [00:02<00:00, 390.70it/s]
# Processing test: 100%|█████████████████████| 6702/6702 [00:16<00:00, 407.06it/s]

# %%
# !torchrun --nnodes 1 --nproc_per_node 1 run.py args/aokvqa_vanilla_eval.yaml

# %%
# !torchrun --nnodes 1 --nproc_per_node 1 run.py args/aokvqa_cot.yaml
# Out:
# 2025-07-09 14:35:16,258 - __main__ - INFO - MultiCoCoRunner initialized for training
# 2025-07-09 14:35:16,259 - __main__ - INFO - CoT training phase - no latent tokens added
# 2025-07-09 14:35:16,259 - __main__ - INFO - Loading base model: OpenGVLab/InternVL3-1B-Pretrained
# 2025-07-09 14:35:16,750 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_select_layer: -1
# 2025-07-09 14:35:16,751 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - ps_version: v2
# 2025-07-09 14:35:16,751 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - min_dynamic_patch: 1
# 2025-07-09 14:35:16,751 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - max_dynamic_patch: 12
# 2025-07-09 14:35:16,751 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_config is None. Initializing the InternVisionConfig with default values.
# 2025-07-09 14:35:16,752 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - llm_config is None. Initializing the LlamaConfig config with default values (`LlamaConfig`).
# 2025-07-09 14:35:16,752 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - vision_select_layer: -1
# 2025-07-09 14:35:16,752 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - ps_version: v1
# 2025-07-09 14:35:16,752 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - min_dynamic_patch: 1
# 2025-07-09 14:35:16,752 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.configuration_internvl_chat - INFO - max_dynamic_patch: 6
# FlashAttention2 is not installed.
# 2025-07-09 14:35:17,972 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.modeling_internvl_chat - INFO - num_image_token: 256
# 2025-07-09 14:35:17,973 - transformers_modules.OpenGVLab.InternVL3-1B-Pretrained.d3292416b2ecc894c0f4009a6dae424fbf164249.modeling_internvl_chat - INFO - ps_version: v2
# 2025-07-09 14:35:19,534 - multicoco.model - INFO - MultiCoCo model initialized with 938193024 parameters
# 2025-07-09 14:35:19,534 - __main__ - INFO - Base model 'OpenGVLab/InternVL3-1B-Pretrained' initialized successfully
# 2025-07-09 14:35:19,534 - __main__ - INFO - Model dtype: bfloat16
# 2025-07-09 14:35:19,534 - __main__ - INFO - Model precision - BF16: True, FP16: False
# 2025-07-09 14:35:19,534 - __main__ - INFO - Training mode: cot_train
# 2025-07-09 14:35:19,534 - __main__ - INFO - CoCoNut enabled: False
# 2025-07-09 14:35:19,563 - multicoco.data - INFO - Loaded 17056 samples from /workspace/multicoco/data/aokvqa_train.json
# 2025-07-09 14:35:19,563 - __main__ - INFO - Training dataset loaded with 17056 samples
# 2025-07-09 14:35:19,566 - multicoco.data - INFO - Loaded 1145 samples from /workspace/multicoco/data/aokvqa_validation.json
# 2025-07-09 14:35:19,566 - __main__ - INFO - Evaluation dataset loaded with 1145 samples
# 2025-07-09 14:35:19,566 - __main__ - INFO - Starting CoT training...
# 2025-07-09 14:35:19,977 - multicoco.trainer - INFO - CoCoTrainer initialized.
# 2025-07-09 14:35:19,978 - __main__ - INFO - Trainer created successfully
# 2025-07-09 14:35:19,978 - __main__ - INFO - Starting training...
# /opt/jupyter_venv/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# [rank0]:[W709 14:35:19.499114684 ProcessGroupNCCL.cpp:4718] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 as device used by this process is currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. You can pecify device_id in init_process_group() to force use of a particular device.
# wandb: Currently logged in as: gunadeep2005 (gunadeep2005-pes-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.21.0
# wandb: Run data is saved locally in /workspace/multicoco/wandb/run-20250709_143520-speptizg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run aokvqa-cot-stage0
# wandb: ⭐️ View project at https://wandb.ai/gunadeep2005-pes-university/multicoco
# wandb: 🚀 View run at https://wandb.ai/gunadeep2005-pes-university/multicoco/runs/speptizg
# 2025-07-09 14:35:21,337 - multicoco.trainer - INFO - Resuming training from checkpoint: checkpoints/aokvqa_cot/checkpoint-epoch-3
# 2025-07-09 14:35:21,537 - multicoco.trainer - INFO - Loaded training info: resuming from epoch 4
# 2025-07-09 14:35:21,538 - multicoco.trainer - INFO - Starting epoch-based training:
# 2025-07-09 14:35:21,538 - multicoco.trainer - INFO -   Steps per epoch: 533
# 2025-07-09 14:35:21,538 - multicoco.trainer - INFO -   Total epochs: 10
# 2025-07-09 14:35:21,539 - multicoco.trainer - INFO -   Total steps: 5330
# 2025-07-09 14:35:21,554 - multicoco.trainer - INFO -
# Starting Epoch 4/10
# Epoch 4/10: 100%|██| 533/533 [04:48<00:00,  1.85it/s, loss=1.1562, step=533/533]
# 2025-07-09 14:40:10,280 - multicoco.trainer - INFO -   Training completed - Average loss: 1.3224
# 2025-07-09 14:40:12,513 - multicoco.trainer - INFO -   Checkpoint saved: checkpoints/aokvqa_cot/checkpoint-epoch-4
# 2025-07-09 14:40:12,514 - multicoco.trainer - INFO -   Running evaluation after epoch 4...
# 2025-07-09 14:40:47,040 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-09 14:40:47,041 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# Evaluation: 100%|███████████████████████████████| 36/36 [01:23<00:00,  2.33s/it]
# /opt/jupyter_venv/lib/python3.10/site-packages/torch/distributed/distributed_c10d.py:4631: UserWarning: No device id is provided via `init_process_group` or `barrier `. Using the current device set by the user.
#   warnings.warn(  # warn only once
# 2025-07-09 14:41:36,371 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-09 14:41:36,379 - multicoco.trainer - INFO -   New best accuracy: 0.6917
# 2025-07-09 14:41:36,379 - multicoco.trainer - INFO -
# Epoch 4 Summary:
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO -   Training time: 374.83s
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO -   Evaluation accuracy: 0.6917
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO -   Best accuracy so far: 0.6917
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO -   Checkpoint saved to: checkpoints/aokvqa_cot/checkpoint-epoch-4
# 2025-07-09 14:41:36,380 - multicoco.trainer - INFO - ================================================================================
# 2025-07-09 14:41:36,576 - multicoco.trainer - INFO -
# Starting Epoch 5/10
# Epoch 5/10:   0%|                                       | 0/533 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Epoch 5/10: 100%|██| 533/533 [04:49<00:00,  1.84it/s, loss=1.1172, step=533/533]
# 2025-07-09 14:46:26,364 - multicoco.trainer - INFO -   Training completed - Average loss: 1.2644
# 2025-07-09 14:46:28,683 - multicoco.trainer - INFO -   Checkpoint saved: checkpoints/aokvqa_cot/checkpoint-epoch-5
# 2025-07-09 14:46:28,684 - multicoco.trainer - INFO -   Running evaluation after epoch 5...
# Evaluation:   0%|                                        | 0/36 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2025-07-09 14:47:03,989 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-09 14:47:03,990 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# Evaluation: 100%|███████████████████████████████| 36/36 [01:25<00:00,  2.37s/it]
# 2025-07-09 14:47:54,175 - multicoco.trainer - WARNING - Could not extract valid choice from: 21
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -
# Epoch 5 Summary:
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -   Training time: 377.60s
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -   Evaluation accuracy: 0.6900
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -   Best accuracy so far: 0.6917
# 2025-07-09 14:47:54,180 - multicoco.trainer - INFO -   Checkpoint saved to: checkpoints/aokvqa_cot/checkpoint-epoch-5
# 2025-07-09 14:47:54,181 - multicoco.trainer - INFO - ================================================================================
# 2025-07-09 14:47:54,449 - multicoco.trainer - INFO -
# Starting Epoch 6/10
# Epoch 6/10:   0%|                                       | 0/533 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Epoch 6/10: 100%|██| 533/533 [04:51<00:00,  1.83it/s, loss=1.4219, step=533/533]
# 2025-07-09 14:52:46,258 - multicoco.trainer - INFO -   Training completed - Average loss: 1.2238
# 2025-07-09 14:52:48,579 - multicoco.trainer - INFO -   Checkpoint saved: checkpoints/aokvqa_cot/checkpoint-epoch-6
# 2025-07-09 14:52:48,579 - multicoco.trainer - INFO -   Running evaluation after epoch 6...
# Evaluation:   0%|                                        | 0/36 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluation: 100%|███████████████████████████████| 36/36 [01:24<00:00,  2.36s/it]
# 2025-07-09 14:54:13,432 - multicoco.trainer - INFO -   New best accuracy: 0.6987
# 2025-07-09 14:54:13,432 - multicoco.trainer - INFO -
# Epoch 6 Summary:
# 2025-07-09 14:54:13,432 - multicoco.trainer - INFO -   Training time: 378.98s
# 2025-07-09 14:54:13,432 - multicoco.trainer - INFO -   Evaluation accuracy: 0.6987
# 2025-07-09 14:54:13,432 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-09 14:54:13,433 - multicoco.trainer - INFO -   Best accuracy so far: 0.6987
# 2025-07-09 14:54:13,433 - multicoco.trainer - INFO -   Checkpoint saved to: checkpoints/aokvqa_cot/checkpoint-epoch-6
# 2025-07-09 14:54:13,433 - multicoco.trainer - INFO - ================================================================================
# 2025-07-09 14:54:13,740 - multicoco.trainer - INFO -
# Starting Epoch 7/10
# Epoch 7/10:   0%|                                       | 0/533 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Epoch 7/10: 100%|██| 533/533 [04:53<00:00,  1.82it/s, loss=0.7734, step=533/533]
# 2025-07-09 14:59:07,014 - multicoco.trainer - INFO -   Training completed - Average loss: 1.2014
# 2025-07-09 14:59:09,197 - multicoco.trainer - INFO -   Checkpoint saved: checkpoints/aokvqa_cot/checkpoint-epoch-7
# 2025-07-09 14:59:09,197 - multicoco.trainer - INFO -   Running evaluation after epoch 7...
# Evaluation:   0%|                                        | 0/36 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluation: 100%|███████████████████████████████| 36/36 [01:21<00:00,  2.26s/it]
# 2025-07-09 15:00:30,590 - multicoco.trainer - INFO -
# Epoch 7 Summary:
# 2025-07-09 15:00:30,590 - multicoco.trainer - INFO -   Training time: 376.85s
# 2025-07-09 15:00:30,591 - multicoco.trainer - INFO -   Evaluation accuracy: 0.6908
# 2025-07-09 15:00:30,591 - multicoco.trainer - INFO -   Evaluation loss: -1.0000
# 2025-07-09 15:00:30,591 - multicoco.trainer - INFO -   Best accuracy so far: 0.6987
# 2025-07-09 15:00:30,591 - multicoco.trainer - INFO -   Checkpoint saved to: checkpoints/aokvqa_cot/checkpoint-epoch-7
# 2025-07-09 15:00:30,591 - multicoco.trainer - INFO - ================================================================================
# 2025-07-09 15:00:30,889 - multicoco.trainer - INFO -
# Starting Epoch 8/10
# Epoch 8/10:   0%|                                       | 0/533 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Epoch 8/10: 100%|██| 533/533 [04:47<00:00,  1.85it/s, loss=0.9961, step=533/533]
# 2025-07-09 15:05:18,689 - multicoco.trainer - INFO -   Training completed - Average loss: 1.1914
# 2025-07-09 15:05:21,110 - multicoco.trainer - INFO -   Checkpoint saved: checkpoints/aokvqa_cot/checkpoint-epoch-8
# 2025-07-09 15:05:21,111 - multicoco.trainer - INFO -   Running evaluation after epoch 8...
# Evaluation:   0%|                                        | 0/36 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Evaluation:  75%|███████████████████████▎       | 27/36 [01:02<00:20,  2.27s/it]^C
# W0709 15:06:23.594000 9392 torch/distributed/elastic/agent/server/api.py:719] Received Signals.SIGINT death signal, shutting down workers
# W0709 15:06:23.594000 9392 torch/distributed/elastic/multiprocessing/api.py:900] Sending process 9463 closing signal SIGINT
# Evaluation:  75%|███████████████████████▎       | 27/36 [01:02<00:20,  2.32s/it]
#
# Interrupted by user
